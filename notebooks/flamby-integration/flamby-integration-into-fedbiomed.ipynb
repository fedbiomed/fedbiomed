# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Fed-IXI

# %%
#from fedbiomed.common.data import DataManager
from fedbiomed.common.training_plans import FlambyTrainingPlan
import torch.nn as nn
from torch.optim import AdamW
from unet import UNet

class UNetTrainingPlan(FlambyTrainingPlan):
    # Init of UNetTrainingPlan
    def __init__(self, model_args: dict = {}):
        super(UNetTrainingPlan, self).__init__(model_args)
        self.CHANNELS_DIMENSION = 1
        
        self.unet = UNet(
            in_channels = model_args.get('in_channels',1),
            out_classes = model_args.get('out_classes',2),
            dimensions = model_args.get('dimensions',2),
            num_encoding_blocks = model_args.get('num_encoding_blocks',5),
            out_channels_first_layer = model_args.get('out_channels_first_layer',64),
            normalization = model_args.get('normalization', None),
            pooling_type = model_args.get('pooling_type', 'max'),
            upsampling_type = model_args.get('upsampling_type','conv'),
            preactivation = model_args.get('preactivation',False),
            residual = model_args.get('residual',False),
            padding = model_args.get('padding',0),
            padding_mode = model_args.get('padding_mode','zeros'),
            activation = model_args.get('activation','ReLU'),
            initial_dilation = model_args.get('initial_dilation',None),
            dropout = model_args.get('dropout',0),
            monte_carlo_dropout = model_args.get('monte_carlo_dropout',0)
        )
        
        
        # Here we define the custom dependencies that will be needed by our custom Dataloader
        deps = ["import torch.nn as nn",
               'import torch.nn.functional as F',
               'from torch.optim import AdamW',
               'from unet import UNet']
        self.add_dependency(deps)
        
        self.optimizer = AdamW(self.parameters())

    def forward(self, x):
        x = self.unet.forward(x)
        x = F.softmax(x, dim=self.CHANNELS_DIMENSION)
        return x
    
    @staticmethod
    def get_dice_loss(output, target, epsilon=1e-9):
        CHANNELS_DIMENSION = 1
        SPATIAL_DIMENSIONS = 2, 3, 4
        p0 = output
        g0 = target
        p1 = 1 - p0
        g1 = 1 - g0
        tp = (p0 * g0).sum(dim=SPATIAL_DIMENSIONS)
        fp = (p0 * g1).sum(dim=SPATIAL_DIMENSIONS)
        fn = (p1 * g0).sum(dim=SPATIAL_DIMENSIONS)
        num = 2 * tp
        denom = 2 * tp + fp + fn + epsilon
        dice_score = num / denom
        return 1. - dice_score
    
    def training_step(self, data, target):
        #this function must return the loss to backward it 
        img = data
        output = self.forward(img)
        loss = UNetTrainingPlan.get_dice_loss(output, target)
        avg_loss = loss.mean()
        return avg_loss
    
    def testing_step(self, data, target):
        img = data
        prediction = self.forward(img)
        loss = UNetTrainingPlan.get_dice_loss(prediction, target)
        avg_loss = loss.mean()  # average per batch
        return avg_loss

# %%
model_args = {
    'in_channels': 1,
    'out_classes': 2,
    'dimensions': 3,
    'num_encoding_blocks': 3,
    'out_channels_first_layer': 8,
    'normalization': 'batch',
    'upsampling_type': 'linear',
    'padding': True,
    'activation': 'PReLU',
}

training_args = {
    'batch_size': 16,
    'lr': 0.001,
    'num_updates': 1,
    'dry_run': False,
    'log_interval': 2,
    'test_ratio' : 0.0,
    'test_on_global_updates': False,
    'test_on_local_updates': False,
}

# %% [markdown]
# *train_transform_flamby* key in **training_args** can optionally be used to perform extra transformations on a flamby dataset.
#
# As a reminder, flamby datasets are already internally handling a transformation through their dataloader (this internal transform
# is the one officially used for the flamby benchmark). Thus, one should check what is already performed on the flamby side before
# adding transforms through the researcher.
#
# *train_transform_flamby* has to be defined as a list containing two elements:
# - the first is the imports needed to perform the transformation
# - the second is the Compose object that will be used to input the transform parameter of the flamby dataset federated class
#
# Example:
# ```python
# training_args = {
#     ...,
#     'train_transform_flamby':["from monai.transforms import (Compose, NormalizeIntensity, Resize,)",
#                          "Compose([Resize((48,60,48)), NormalizeIntensity()])"]
# }
# ```

# %%
from fedbiomed.researcher.experiment import Experiment
from fedbiomed.researcher.aggregators.fedavg import FedAverage

tags =  ['ixi']
num_rounds = 1

exp = Experiment(tags=tags,
                 model_args=model_args,
                 model_class=UNetTrainingPlan,
                 training_args=training_args,
                 round_limit=num_rounds,
                 aggregator=FedAverage(),
                )

# %%
exp.run_once(increase=True)

# %% [markdown]
# ### Fed-Heart-Disease

# %%
import torch
import torch.nn as nn
from fedbiomed.common.training_plans import FlambyTrainingPlan
from torch.optim import Adam

class FedHeartTrainingPlan(FlambyTrainingPlan):
    # Init of FedHeartTrainingPlan
    def __init__(self, model_args: dict = {}):
        super(FedHeartTrainingPlan, self).__init__(model_args)

        self.model = nn.Linear(13, 1)
        self.optimizer = Adam(self.parameters())

        self.add_dependency(["from torch.optim import Adam",
                             "import torch.nn as nn"])

    def forward(self, x):
        return torch.sigmoid(self.model(x))

    def training_step(self, data, target):
        #this function must return the loss to backward it
        output = self.forward(data)
        bce = nn.BCELoss()
        loss = bce(output, target)
        return loss

# %%
training_args = {
    'batch_size': 16,
    'lr': 0.001,
    'num_updates': 199,
    'dry_run': False,
    'log_interval': 2,
    'test_ratio' : 0.0,
    'test_on_global_updates': False,
    'test_on_local_updates': False,
}

# %%
from fedbiomed.researcher.experiment import Experiment
from fedbiomed.researcher.aggregators.fedavg import FedAverage

tags =  ['flh0r2']
num_rounds = 2

exp = Experiment(tags=tags,
                 model_class=FedHeartTrainingPlan,
                 training_args=training_args,
                 round_limit=num_rounds,
                 aggregator=FedAverage(),
                )
# Out:
# 2022-09-15 16:49:57,317 fedbiomed INFO - Component environment:
# 2022-09-15 16:49:57,318 fedbiomed INFO - type = ComponentType.RESEARCHER
# 2022-09-15 16:49:57,601 fedbiomed INFO - Messaging researcher_913d067a-29a3-4944-ad2f-a6ab2bfef155 successfully connected to the message broker, object = <fedbiomed.common.messaging.Messaging object at 0x1365a0eb0>
# 2022-09-15 16:49:57,682 fedbiomed INFO - Searching dataset with data tags: ['flh0r2'] for all nodes
# 2022-09-15 16:50:07,714 fedbiomed INFO - Node selected for training -> node_f142c116-190b-415a-af87-7a27dfaedf94
# 2022-09-15 16:50:07,718 fedbiomed DEBUG - Model file has been saved: /Users/fcremone/dev/fedbiomed/var/experiments/Experiment_0010/my_model_b2432e95-997c-4f33-8298-2c62c77dba24.py
# 2022-09-15 16:50:07,760 fedbiomed DEBUG - upload (HTTP POST request) of file /Users/fcremone/dev/fedbiomed/var/experiments/Experiment_0010/my_model_b2432e95-997c-4f33-8298-2c62c77dba24.py successful, with status code 201
# 2022-09-15 16:50:07,800 fedbiomed DEBUG - upload (HTTP POST request) of file /Users/fcremone/dev/fedbiomed/var/experiments/Experiment_0010/aggregated_params_init_3408d812-0ac6-432c-9e32-7faf76b3077f.pt successful, with status code 201

# %%
exp.run_once(increase=True)
# Out:
# 2022-09-15 16:50:31,941 fedbiomed INFO - Sampled nodes in round 1 ['node_f142c116-190b-415a-af87-7a27dfaedf94']
# 2022-09-15 16:50:31,942 fedbiomed INFO - Sending request
# 					 To: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Request: : Perform training with the arguments: {'researcher_id': 'researcher_913d067a-29a3-4944-ad2f-a6ab2bfef155', 'job_id': 'a996ee26-060a-402c-87f6-21de4d93216f', 'training_args': scheme:
# {'lr': {'rules': [<class 'float'>, <function TrainingArgs._lr_hook at 0x1363a01f0>], 'required': False}, 'batch_size': {'rules': [<class 'int'>], 'required': False}, 'num_updates': {'rules': [<class 'int'>], 'required': False}, 'dry_run': {'rules': [<class 'bool'>], 'required': False}, 'batch_maxnum': {'rules': [<class 'int'>], 'required': False}, 'test_ratio': {'rules': [<class 'float'>, <function TrainingArgs._test_ratio_hook at 0x1363a00d0>], 'required': False, 'default': 0.0}, 'test_on_local_updates': {'rules': [<class 'bool'>], 'required': False, 'default': False}, 'test_on_global_updates': {'rules': [<class 'bool'>], 'required': False, 'default': False}, 'test_metric': {'rules': [<function TrainingArgs._metric_validation_hook at 0x136393f70>], 'required': False, 'default': None}, 'test_metric_args': {'rules': [<class 'dict'>], 'required': False, 'default': {}}, 'log_interval': {'rules': [<class 'int'>], 'required': False}, 'train_transform_flamby': {'rules': [<class 'list'>], 'required': False}, 'fedprox_mu': {'rules': [<class 'float'>], 'required': False}}
# value:
# {'batch_size': 16, 'lr': 0.001, 'num_updates': 199, 'dry_run': False, 'log_interval': 2, 'test_ratio': 0.0, 'test_on_global_updates': False, 'test_on_local_updates': False, 'test_metric': None, 'test_metric_args': {}}, 'training': True, 'model_args': {}, 'command': 'train', 'model_url': 'http://localhost:8844/media/uploads/2022/09/15/my_model_b2432e95-997c-4f33-8298-2c62c77dba24.py', 'params_url': 'http://localhost:8844/media/uploads/2022/09/15/aggregated_params_f148f630-4f7f-4866-b560-ca6294a99cd3.pt', 'model_class': 'FedHeartTrainingPlan', 'training_data': {'node_f142c116-190b-415a-af87-7a27dfaedf94': ['dataset_939c1a5c-7cc2-4ad4-a023-a43ad452a8a8']}}
#  -----------------------------------------------------------------
# 2022-09-15 16:50:31,943 fedbiomed DEBUG - researcher_913d067a-29a3-4944-ad2f-a6ab2bfef155
# 2022-09-15 16:50:32,014 fedbiomed INFO - WARNING
# 					 NODE node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 MESSAGE: There is no validation activated for the round. Please set flag for `test_on_global_updates`, `test_on_loc_set_training_testing_data_loadersal_updates`, or both. Splitting dataset for validation will be ignored
# -----------------------------------------------------------------
# 2022-09-15 16:50:32,214 fedbiomed INFO - INFO
# 					 NODE node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 MESSAGE: training with arguments {'history_monitor': <fedbiomed.node.history_monitor.HistoryMonitor object at 0x174bb6ac0>, 'node_args': {'gpu': False, 'gpu_num': None, 'gpu_only': False}, 'lr': 0.001, 'num_updates': 199, 'dry_run': False, 'log_interval': 2}
# -----------------------------------------------------------------
# 2022-09-15 16:50:32,216 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 0 | Completed: 32/199 (16%)
#  					 Loss: 0.698708
# 					 ---------
# 2022-09-15 16:50:32,219 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch:
fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 12 | Completed: 192/199 (96%)
#  					 Loss: 0.368172
# 					 ---------
# 2022-09-15 16:50:32,458 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 13 | Completed: 16/199 (8%)
#  					 Loss: 0.367388
# 					 ---------
# 2022-09-15 16:50:32,460 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 13 | Completed: 48/199 (24%)
#  					 Loss: 0.548011
# 					 ---------
# 2022-09-15 16:50:32,463 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 13 | Completed: 80/199 (40%)
#  					 Loss: 0.447004
# 					 ---------
# 2022-09-15 16:50:32,465 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 13 | Completed: 112/199 (56%)
#  					 Loss: 0.610857
# 					 ---------
# 2022-09-15 16:50:32,467 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 13 | Completed: 144/199 (72%)
#  					 Loss: 0.374969
# 					 ---------
# 2022-09-15 16:50:32,468 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 13 | Completed: 176/199 (88%)
#  					 Loss: 0.466556
# 					 ---------
# 2022-09-15 16:50:32,470 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 13 | Completed: 199/199 (100%)
#  					 Loss: 0.593964
# 					 ---------
# 2022-09-15 16:50:32,473 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 14 | Completed: 32/199 (16%)
#  					 Loss: 0.422115
# 					 ---------
# 2022-09-15 16:50:32,476 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 14 | Completed: 64/199 (32%)
#  					 Loss: 0.472459
# 					 ---------
# 2022-09-15 16:50:32,480 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 14 | Completed: 96/199 (48%)
#  					 Loss: 0.378835
# 					 ---------
# 2022-09-15 16:50:32,482 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 14 | Completed: 128/199 (64%)
#  					 Loss: 0.270734
# 					 ---------
# 2022-09-15 16:50:32,485 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 14 | Completed: 160/199 (80%)
#  					 Loss: 0.484520
# 					 ---------
# 2022-09-15 16:50:32,487 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 14 | Completed: 192/199 (96%)
#  					 Loss: 0.447250
# 					 ---------
# 2022-09-15 16:50:32,488 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 15 | Completed: 16/199 (8%)
#  					 Loss: 0.464121
# 					 ---------
# 2022-09-15 16:50:32,492 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 Epoch: 15 | Completed: 48/199 (24%)
#  					 Loss: 0.436061
# 					 ---------
# 2022-09-15 16:50:32,568 fedbiomed INFO - INFO
# 					 NODE node_f142c116-190b-415a-af87-7a27dfaedf94
# 					 MESSAGE: results uploaded successfully
# -----------------------------------------------------------------
# 2022-09-15 16:50:41,963 fedbiomed INFO - Downloading model params after training on node_f142c116-190b-415a-af87-7a27dfaedf94 - from http://localhost:8844/media/uploads/2022/09/15/node_params_10d714c0-1f17-4d62-acc6-7fcc1b25f252.pt
# 2022-09-15 16:50:41,979 fedbiomed DEBUG - upload (HTTP GET request) of file node_params_29e02e73-7eec-4d79-8984-1e7768dbe693.pt successful, with status code 200
# 2022-09-15 16:50:42,010 fedbiomed INFO - Nodes that successfully reply in round 1 ['node_f142c116-190b-415a-af87-7a27dfaedf94']
# 2022-09-15 16:50:42,055 fedbiomed DEBUG - upload (HTTP POST request) of file /Users/fcremone/dev/fedbiomed/var/experiments/Experiment_0010/aggregated_params_beaa2d8b-39ea-4871-8b19-e27d522fbed7.pt successful, with status code 201
# 2022-09-15 16:50:42,056 fedbiomed INFO - Saved aggregated params for round 1 in /Users/fcremone/dev/fedbiomed/var/experiments/Experiment_0010/aggregated_params_beaa2d8b-39ea-4871-8b19-e27d522fbed7.pt
# 1
