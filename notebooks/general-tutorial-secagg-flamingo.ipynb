# %% [markdown]
# # Training with Secure Aggregation
# Secure aggregation is one of the security feature that is provided by Fed-BioMed. Please refer to secure aggregation user guide for more information regarding the methods and techniques that are used. This tutorial gives an example of secure aggregation usage in Fed-BioMed.

# %% [markdown]
# ## Setting up the nodes
#
# During the tutorial, nodes and researcher will be launched locally using single clone of Fed-BioMed. However, it is also possible to execute notebook cells when the components are configured remotely by respecting following instruction.
#
# ### Start the network
# Before running this notebook, start the network with `./scripts/fedbiomed_run network`
#
# ### Configuring/Installing  Element for Secure Aggregation
#
# You can follow the detailed instructions for configuring Fed-BioMed instance for secure aggregation] or apply following shortened instructions for a basic setup.
#
# #### 1. Install and configure
#
# Fed-BioMed uses MP-SPDZ for MPC. Therefore, please make sure that MP-SPDZ are installed and configured for Fed-BioMed by running following command.
#
#
# ```
# ${FEDBIOMED_DIR}/scripts/fedbiomed_configure_secagg node
# ```
#
# <div class="Note">
#     <p>Since node and researcher will be run in the same machine, single configuration for MP-SDPZ will enouhg</>
# </div>
#
# #### 2. Create node and researcher instances
#
# The setup for secure aggregation requires knowledge of the participating Fed-BioMed components in advance. Therefore, each component that will participate in the training should be created before starting them. Afterwards, participating components can be registered in every other component.
#
# ##### 2.1
# It is mandatory to have at least two nodes for the experiment that requires secure aggregation. Please execute following commands to create two nodes.
#
# Node 1:
# ```
# ${FEDBIOMED_DIR}/scripts/fedbiomed_run node config config-n1.ini configuration create
# ```
#
# Node 2:
# ```
# ${FEDBIOMED_DIR}/scripts/fedbiomed_run node config config-n2.ini configuration create
# ```
#
# ##### 2.2 Create researcher
#
# Please run the command below to create researcher component.
#
# ```
# ${FEDBIOMED_DIR}/scripts/fedbiomed_run researcher configuration create
# ```
#
#
# #### 3. Registering participating Fed-BioMed instances
#
# Normally, as it is mentioned in secure aggregation configuration each participating instance should register network credentials of others such as IP, port and SSL certificate. however, since this example will be run on single clone of Fed-BioMed, registration process can be done automaticity by running following command.
#
# ```
# ${FEDBIOMED_DIR}/scripts/fedbiomed_run certicate-dev-setup
# ```
#
# #### 4. Add dataset and start nodes
#
# The next step will be adding/deploying MNIST dataset in the nodes and starting them. For these step you can follow the instructions for adding dataset into nodes to add MNIST dataset. After the datasets are deployed you can start the nodes and researcher.

# %% [markdown]
# ### Define an experiment model and parameters"

# %% [markdown]
# Declare a torch training plan MyTrainingPlan class to send for training on the node

# %%
import torch
import torch.nn as nn
from fedbiomed.common.training_plans import TorchTrainingPlan
from fedbiomed.common.data import DataManager
from torchvision import datasets, transforms


# Here we define the model to be used. 
# You can use any class name (here 'Net')
class MyTrainingPlan(TorchTrainingPlan):
    
    # Defines and return model 
    def init_model(self, model_args):
        return self.Net(model_args = model_args)
    
    # Defines and return optimizer
    def init_optimizer(self, optimizer_args):
        return torch.optim.Adam(self.model().parameters(), lr = optimizer_args["lr"])
    
    # Declares and return dependencies
    def init_dependencies(self):
        deps = ["from torchvision import datasets, transforms"]
        return deps
    
    class Net(nn.Module):
        def __init__(self, model_args):
            super().__init__()
            self.conv1 = nn.Conv2d(1, 32, 3, 1)
            self.conv2 = nn.Conv2d(32, 64, 3, 1)
            self.dropout1 = nn.Dropout(0.25)
            self.dropout2 = nn.Dropout(0.5)
            self.fc1 = nn.Linear(9216, 128)
            self.fc2 = nn.Linear(128, 10)

        def forward(self, x):
            x = self.conv1(x)
            x = F.relu(x)
            x = self.conv2(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)
            x = self.dropout1(x)
            x = torch.flatten(x, 1)
            x = self.fc1(x)
            x = F.relu(x)
            x = self.dropout2(x)
            x = self.fc2(x)


            output = F.log_softmax(x, dim=1)
            return output

    def training_data(self):
        # Custom torch Dataloader for MNIST data
        transform = transforms.Compose([transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))])
        dataset1 = datasets.MNIST(self.dataset_path, train=True, download=False, transform=transform)
        train_kwargs = { 'shuffle': True}
        return DataManager(dataset=dataset1, **train_kwargs)
    
    def training_step(self, data, target):
        output = self.model().forward(data)
        loss   = torch.nn.functional.nll_loss(output, target)
        return loss

# %% [markdown]
# This group of arguments correspond respectively:
# * `model_args`: a dictionary with the arguments related to the model (e.g. number of layers, features, etc.). This will be passed to the model class on the node side.
# * `training_args`: a dictionary containing the arguments for the training routine (e.g. batch size, learning rate, epochs, etc.). This will be passed to the routine on the node side.
#
# **NOTE:** typos and/or lack of positional (required) arguments will raise error. 🤓

# %%
model_args = {}

training_args = {
    'loader_args': { 'batch_size': 48, }, 
    'optimizer_args': {
        "lr" : 1e-3
    },
    'epochs': 1, 
    'dry_run': False,  
    'batch_maxnum': 100 # Fast pass for development : only use ( batch_maxnum * batch_size ) samples
}

# %% [markdown]
# ### Declare and run the experiment

# %%
from fedbiomed.researcher.experiment import Experiment
from fedbiomed.researcher.aggregators.fedavg import FedAverage
from fedbiomed.researcher.secagg import SecureAggregation
tags =  ['#MNIST', '#dataset']
rounds = 2

exp = Experiment(tags=tags,
                 model_args=model_args,
                 training_plan_class=MyTrainingPlan,
                 training_args=training_args,
                 round_limit=rounds,
                 aggregator=FedAverage(),
                 node_selection_strategy=None,
                 secagg=SecureAggregation(active=True, scheme='flamingo'), # or custom SecureAggregation(active=<bool>, clipping_range=<int>)
                 save_breakpoints=True,
                tensorboard=True)
# Out:
# 2023-11-30 17:47:50,031 fedbiomed DEBUG - Node: node_a3caf782-3838-4b43-a629-0b004bd18194 polling for the tasks
# 2023-11-30 17:47:50,032 fedbiomed DEBUG - Node: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d polling for the tasks
# 2023-11-30 17:47:50,034 fedbiomed DEBUG - Node: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46 polling for the tasks
# 2023-11-30 17:47:50,037 fedbiomed INFO - Node selected for training -> node_a3caf782-3838-4b43-a629-0b004bd18194
# 2023-11-30 17:47:50,037 fedbiomed INFO - Node selected for training -> node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 2023-11-30 17:47:50,038 fedbiomed INFO - Node selected for training -> node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 2023-11-30 17:47:50,041 fedbiomed DEBUG - Model file has been saved: /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/model_98dc48c9-b4dc-4326-831c-4988759290fc.py
# Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# 2023-11-30 17:47:50,062 fedbiomed DEBUG - using native torch optimizer
# 2023-11-30 17:47:50,063 fedbiomed INFO - Removing tensorboard logs from previous experiment

# %%
from fedbiomed.researcher.environ import environ
tensorboard_dir = environ['TENSORBOARD_RESULTS_DIR']

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# %tensorboard --logdir "$tensorboard_dir"
# Out:
# Reusing TensorBoard on port 6006 (pid 35673), started 0:03:36 ago. (Use '!kill 35673' to kill it.)
#       <iframe id="tensorboard-frame-de1d7c2d5a433514" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-de1d7c2d5a433514");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
exp.run(rounds=5, increase=True)
# Out:
# 2023-11-30 17:47:59,644 fedbiomed DEBUG - Auto increasing total rounds for experiment from 2 to 5
# 2023-11-30 17:47:59,648 fedbiomed INFO - Sampled nodes in round 0 ['node_a3caf782-3838-4b43-a629-0b004bd18194', 'node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d', 'node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46']
# 2023-11-30 17:47:59,657 fedbiomed INFO - Sending request
# 					 To: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:47:59,660 fedbiomed INFO - Sending request
# 					 To: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:47:59,663 fedbiomed INFO - Sending request
# 					 To: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:47:59,731 fedbiomed DEBUG - Node: node_a3caf782-3838-4b43-a629-0b004bd18194 polling for the tasks
# 2023-11-30 17:47:59,741 fedbiomed DEBUG - Node: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d polling for the tasks
# 2023-11-30 17:47:59,761 fedbiomed DEBUG - Node: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46 polling for the tasks
# 2023-11-30 17:47:59,922 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 2.311095
# 					 ---------
# 2023-11-30 17:48:00,570 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 2.303904
# 					 ---------
# 2023-11-30 17:48:00,684 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 2.283457
# 					 ---------
# 2023-11-30 17:48:02,860 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 1.526466
# 					 ---------
# 2023-11-30 17:48:03,282 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 1.280058
# 					 ---------
# 2023-11-30 17:48:04,058 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 1.526542
# 					 ---------
# 2023-11-30 17:48:06,228 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.955063
# 					 ---------
# 2023-11-30 17:48:06,684 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 1.087519
# 					 ---------
# 2023-11-30 17:48:07,959 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 1.312439
# 					 ---------
# 2023-11-30 17:48:09,538 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.623971
# 					 ---------
# 2023-11-30 17:48:09,918 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.507535
# 					 ---------
# 2023-11-30 17:48:12,043 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.768167
# 					 ---------
# 2023-11-30 17:48:12,872 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.730141
# 					 ---------
# 2023-11-30 17:48:14,010 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.700543
# 					 ---------
# 2023-11-30 17:48:14,389 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.628422
# 					 ---------
# 2023-11-30 17:48:16,142 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.797482
# 					 ---------
# 2023-11-30 17:48:16,894 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.345162
# 					 ---------
# 2023-11-30 17:48:18,513 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.758156
# 					 ---------
# 2023-11-30 17:48:20,109 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.347669
# 					 ---------
# 2023-11-30 17:48:21,231 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.357427
# 					 ---------
# 2023-11-30 17:48:22,108 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.467432
# 					 ---------
# 2023-11-30 17:48:22,859 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.343906
# 					 ---------
# 2023-11-30 17:48:24,130 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.385823
# 					 ---------
# 2023-11-30 17:48:25,945 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.416581
# 					 ---------
# 2023-11-30 17:48:27,205 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.301188
# 					 ---------
# 2023-11-30 17:48:27,463 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.329093
# 					 ---------
# 2023-11-30 17:48:27,737 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.320210
# 					 ---------
# 2023-11-30 17:48:29,745 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.490049
# 					 ---------
# 2023-11-30 17:48:29,977 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.678510
# 					 ---------
# 2023-11-30 17:48:31,146 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.492956
# 					 ---------
# 2023-11-30 17:48:33,014 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 1 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.244818
# 					 ---------
# 2023-11-30 17:48:33,084 fedbiomed INFO - INFO
# 					 NODE node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:48:33,288 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 1 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.529913
# 					 ---------
# 2023-11-30 17:48:33,329 fedbiomed INFO - INFO
# 					 NODE node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:48:33,425 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 1 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.362681
# 					 ---------
# 2023-11-30 17:48:33,494 fedbiomed INFO - INFO
# 					 NODE node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:48:34,670 fedbiomed INFO - INFO
# 					 NODE node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:48:34,839 fedbiomed INFO - INFO
# 					 NODE node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:48:34,980 fedbiomed INFO - INFO
# 					 NODE node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:48:35,254 fedbiomed INFO - Nodes that successfully reply in round 0 ['node_a3caf782-3838-4b43-a629-0b004bd18194', 'node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d', 'node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46']
# 2023-11-30 17:48:35,254 fedbiomed WARNING - Encryption factors are provided while secagg random is None. Please make sure secure aggregation steps are applied correctly.
# 2023-11-30 17:48:35,255 fedbiomed INFO - Aggregating encrypted parameters. This process may take some time depending on model size.
# 2023-11-30 17:48:35,718 fedbiomed INFO - Aggregating parameters from 3 nodes.
# 2023-11-30 17:48:45,064 fedbiomed DEBUG - Aggregation is completed in 9.75 seconds.
# 2023-11-30 17:48:45,227 fedbiomed INFO - Saved aggregated params for round 0 in /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/aggregated_params_c2fb8fb5-b6be-435f-b3a8-99180d2066a6.mpk
# 2023-11-30 17:48:46,508 fedbiomed INFO - breakpoint for round 0 saved at /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/breakpoint_0000
# 2023-11-30 17:48:46,520 fedbiomed INFO - Sampled nodes in round 1 ['node_a3caf782-3838-4b43-a629-0b004bd18194', 'node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d', 'node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46']
# 2023-11-30 17:48:46,550 fedbiomed INFO - Sending request
# 					 To: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:48:46,550 fedbiomed INFO - Sending request
# 					 To: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:48:46,551 fedbiomed INFO - Sending request
# 					 To: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:48:46,602 fedbiomed DEBUG - Node: node_a3caf782-3838-4b43-a629-0b004bd18194 polling for the tasks
# 2023-11-30 17:48:46,604 fedbiomed DEBUG - Node: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d polling for the tasks
# 2023-11-30 17:48:46,612 fedbiomed DEBUG - Node: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46 polling for the tasks
# 2023-11-30 17:48:46,802 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.303762
# 					 ---------
# 2023-11-30 17:48:46,871 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.352192
# 					 ---------
# 2023-11-30 17:48:47,115 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.345213
# 					 ---------
# 2023-11-30 17:48:49,657 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.170925
# 					 ---------
# 2023-11-30 17:48:51,401 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.430954
# 					 ---------
# 2023-11-30 17:48:51,529 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.400345
# 					 ---------
# 2023-11-30 17:48:54,497 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.264127
# 					 ---------
# 2023-11-30 17:48:54,891 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.299000
# 					 ---------
# 2023-11-30 17:48:57,451 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.238648
# 					 ---------
# 2023-11-30 17:48:58,155 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.533326
# 					 ---------
# 2023-11-30 17:48:59,444 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.287011
# 					 ---------
# 2023-11-30 17:49:00,258 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.192547
# 					 ---------
# 2023-11-30 17:49:00,950 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.340544
# 					 ---------
# 2023-11-30 17:49:03,099 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.263289
# 					 ---------
# 2023-11-30 17:49:03,415 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.303218
# 					 ---------
# 2023-11-30 17:49:04,049 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.269492
# 					 ---------
# 2023-11-30 17:49:06,260 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.046887
# 					 ---------
# 2023-11-30 17:49:06,713 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.242983
# 					 ---------
# 2023-11-30 17:49:06,768 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.416834
# 					 ---------
# 2023-11-30 17:49:09,620 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.246026
# 					 ---------
# 2023-11-30 17:49:10,372 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.045136
# 					 ---------
# 2023-11-30 17:49:10,454 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.237387
# 					 ---------
# 2023-11-30 17:49:12,190 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.137748
# 					 ---------
# 2023-11-30 17:49:12,509 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.239611
# 					 ---------
# 2023-11-30 17:49:13,440 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.182641
# 					 ---------
# 2023-11-30 17:49:14,471 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.185571
# 					 ---------
# 2023-11-30 17:49:16,426 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.109747
# 					 ---------
# 2023-11-30 17:49:18,014 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.220683
# 					 ---------
# 2023-11-30 17:49:18,194 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.159955
# 					 ---------
# 2023-11-30 17:49:18,245 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 2 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.380183
# 					 ---------
# 2023-11-30 17:49:18,340 fedbiomed INFO - INFO
# 					 NODE node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:49:19,377 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 2 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.185852
# 					 ---------
# 2023-11-30 17:49:19,434 fedbiomed INFO - INFO
# 					 NODE node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:49:19,587 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.334878
# 					 ---------
# 2023-11-30 17:49:20,297 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 2 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.334759
# 					 ---------
# 2023-11-30 17:49:20,337 fedbiomed INFO - INFO
# 					 NODE node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:49:20,826 fedbiomed INFO - INFO
# 					 NODE node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:49:21,287 fedbiomed INFO - INFO
# 					 NODE node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:49:21,812 fedbiomed INFO - INFO
# 					 NODE node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:49:22,113 fedbiomed INFO - Nodes that successfully reply in round 1 ['node_a3caf782-3838-4b43-a629-0b004bd18194', 'node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d', 'node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46']
# 2023-11-30 17:49:22,114 fedbiomed WARNING - Encryption factors are provided while secagg random is None. Please make sure secure aggregation steps are applied correctly.
# 2023-11-30 17:49:22,114 fedbiomed INFO - Aggregating encrypted parameters. This process may take some time depending on model size.
# 2023-11-30 17:49:22,595 fedbiomed INFO - Aggregating parameters from 3 nodes.
# 2023-11-30 17:49:33,137 fedbiomed DEBUG - Aggregation is completed in 10.93 seconds.
# 2023-11-30 17:49:33,358 fedbiomed INFO - Saved aggregated params for round 1 in /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/aggregated_params_1d97081b-dbca-4e8e-a6d3-0515d593748f.mpk
# 2023-11-30 17:49:36,392 fedbiomed INFO - breakpoint for round 1 saved at /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/breakpoint_0001
# 2023-11-30 17:49:36,410 fedbiomed INFO - Sampled nodes in round 2 ['node_a3caf782-3838-4b43-a629-0b004bd18194', 'node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d', 'node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46']
# 2023-11-30 17:49:36,444 fedbiomed INFO - Sending request
# 					 To: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:49:36,446 fedbiomed INFO - Sending request
# 					 To: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:49:36,447 fedbiomed INFO - Sending request
# 					 To: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:49:36,513 fedbiomed DEBUG - Node: node_a3caf782-3838-4b43-a629-0b004bd18194 polling for the tasks
# 2023-11-30 17:49:36,517 fedbiomed DEBUG - Node: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d polling for the tasks
# 2023-11-30 17:49:36,521 fedbiomed DEBUG - Node: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46 polling for the tasks
# 2023-11-30 17:49:37,005 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.152366
# 					 ---------
# 2023-11-30 17:49:37,260 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.056786
# 					 ---------
# 2023-11-30 17:49:37,338 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.134694
# 					 ---------
# 2023-11-30 17:49:40,667 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.295985
# 					 ---------
# 2023-11-30 17:49:42,416 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.337457
# 					 ---------
# 2023-11-30 17:49:42,920 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.035919
# 					 ---------
# 2023-11-30 17:49:45,587 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.125407
# 					 ---------
# 2023-11-30 17:49:46,483 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.046130
# 					 ---------
# 2023-11-30 17:49:48,419 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.128438
# 					 ---------
# 2023-11-30 17:49:49,053 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.306165
# 					 ---------
# 2023-11-30 17:49:51,258 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.200482
# 					 ---------
# 2023-11-30 17:49:51,355 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.128479
# 					 ---------
# 2023-11-30 17:49:53,036 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.214391
# 					 ---------
# 2023-11-30 17:49:54,630 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.255887
# 					 ---------
# 2023-11-30 17:49:55,735 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.295812
# 					 ---------
# 2023-11-30 17:49:56,030 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.215475
# 					 ---------
# 2023-11-30 17:49:58,328 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.346123
# 					 ---------
# 2023-11-30 17:49:58,664 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.162138
# 					 ---------
# 2023-11-30 17:50:01,002 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.200193
# 					 ---------
# 2023-11-30 17:50:01,624 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.080725
# 					 ---------
# 2023-11-30 17:50:03,412 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.103505
# 					 ---------
# 2023-11-30 17:50:03,819 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.074025
# 					 ---------
# 2023-11-30 17:50:04,033 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.114187
# 					 ---------
# 2023-11-30 17:50:05,131 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.008727
# 					 ---------
# 2023-11-30 17:50:06,037 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.144278
# 					 ---------
# 2023-11-30 17:50:08,004 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.152486
# 					 ---------
# 2023-11-30 17:50:09,051 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.010553
# 					 ---------
# 2023-11-30 17:50:09,539 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 3 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.225996
# 					 ---------
# 2023-11-30 17:50:09,589 fedbiomed INFO - INFO
# 					 NODE node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:50:10,535 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.238225
# 					 ---------
# 2023-11-30 17:50:11,617 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.102036
# 					 ---------
# 2023-11-30 17:50:12,181 fedbiomed INFO - INFO
# 					 NODE node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:50:12,211 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 3 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.102391
# 					 ---------
# 2023-11-30 17:50:12,282 fedbiomed INFO - INFO
# 					 NODE node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:50:12,848 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.217128
# 					 ---------
# 2023-11-30 17:50:13,616 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 3 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.163204
# 					 ---------
# 2023-11-30 17:50:13,681 fedbiomed INFO - INFO
# 					 NODE node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:50:14,606 fedbiomed INFO - INFO
# 					 NODE node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:50:15,386 fedbiomed INFO - INFO
# 					 NODE node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:50:15,702 fedbiomed INFO - Nodes that successfully reply in round 2 ['node_a3caf782-3838-4b43-a629-0b004bd18194', 'node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d', 'node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46']
# 2023-11-30 17:50:15,703 fedbiomed WARNING - Encryption factors are provided while secagg random is None. Please make sure secure aggregation steps are applied correctly.
# 2023-11-30 17:50:15,704 fedbiomed INFO - Aggregating encrypted parameters. This process may take some time depending on model size.
# 2023-11-30 17:50:16,296 fedbiomed INFO - Aggregating parameters from 3 nodes.
# 2023-11-30 17:50:26,835 fedbiomed DEBUG - Aggregation is completed in 11.04 seconds.
# 2023-11-30 17:50:27,046 fedbiomed INFO - Saved aggregated params for round 2 in /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/aggregated_params_2c12a044-fe01-4330-889f-05577cab9803.mpk
# 2023-11-30 17:50:31,448 fedbiomed INFO - breakpoint for round 2 saved at /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/breakpoint_0002
# 2023-11-30 17:50:31,466 fedbiomed INFO - Sampled nodes in round 3 ['node_a3caf782-3838-4b43-a629-0b004bd18194', 'node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d', 'node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46']
# 2023-11-30 17:50:31,498 fedbiomed INFO - Sending request
# 					 To: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:50:31,499 fedbiomed INFO - Sending request
# 					 To: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:50:31,500 fedbiomed INFO - Sending request
# 					 To: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:50:31,565 fedbiomed DEBUG - Node: node_a3caf782-3838-4b43-a629-0b004bd18194 polling for the tasks
# 2023-11-30 17:50:31,580 fedbiomed DEBUG - Node: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d polling for the tasks
# 2023-11-30 17:50:31,583 fedbiomed DEBUG - Node: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46 polling for the tasks
# 2023-11-30 17:50:32,228 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.114739
# 					 ---------
# 2023-11-30 17:50:32,377 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.233686
# 					 ---------
# 2023-11-30 17:50:33,127 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.164775
# 					 ---------
# 2023-11-30 17:50:35,794 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.280414
# 					 ---------
# 2023-11-30 17:50:38,406 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.121472
# 					 ---------
# 2023-11-30 17:50:39,072 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.086765
# 					 ---------
# 2023-11-30 17:50:41,087 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.124418
# 					 ---------
# 2023-11-30 17:50:43,238 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.065185
# 					 ---------
# 2023-11-30 17:50:45,458 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.036643
# 					 ---------
# 2023-11-30 17:50:46,078 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.202183
# 					 ---------
# 2023-11-30 17:50:46,216 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.144667
# 					 ---------
# 2023-11-30 17:50:47,712 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.138437
# 					 ---------
# 2023-11-30 17:50:48,520 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.084777
# 					 ---------
# 2023-11-30 17:50:50,675 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.021895
# 					 ---------
# 2023-11-30 17:50:51,220 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.183436
# 					 ---------
# 2023-11-30 17:50:53,207 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.176928
# 					 ---------
# 2023-11-30 17:50:54,204 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.203724
# 					 ---------
# 2023-11-30 17:50:54,901 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.275844
# 					 ---------
# 2023-11-30 17:50:55,942 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.408050
# 					 ---------
# 2023-11-30 17:50:58,971 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.196776
# 					 ---------
# 2023-11-30 17:50:59,234 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.069518
# 					 ---------
# 2023-11-30 17:50:59,654 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.248236
# 					 ---------
# 2023-11-30 17:51:01,984 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.110249
# 					 ---------
# 2023-11-30 17:51:02,259 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.132804
# 					 ---------
# 2023-11-30 17:51:04,245 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.088939
# 					 ---------
# 2023-11-30 17:51:04,864 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.283031
# 					 ---------
# 2023-11-30 17:51:05,930 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.111248
# 					 ---------
# 2023-11-30 17:51:06,527 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 4 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.179885
# 					 ---------
# 2023-11-30 17:51:06,645 fedbiomed INFO - INFO
# 					 NODE node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:51:07,849 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.117299
# 					 ---------
# 2023-11-30 17:51:08,692 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.244408
# 					 ---------
# 2023-11-30 17:51:09,049 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.137895
# 					 ---------
# 2023-11-30 17:51:09,151 fedbiomed INFO - INFO
# 					 NODE node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:51:09,939 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 4 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.060403
# 					 ---------
# 2023-11-30 17:51:09,980 fedbiomed INFO - INFO
# 					 NODE node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:51:10,137 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 4 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.122867
# 					 ---------
# 2023-11-30 17:51:10,176 fedbiomed INFO - INFO
# 					 NODE node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:51:11,537 fedbiomed INFO - INFO
# 					 NODE node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:51:11,705 fedbiomed INFO - INFO
# 					 NODE node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:51:12,033 fedbiomed INFO - Nodes that successfully reply in round 3 ['node_a3caf782-3838-4b43-a629-0b004bd18194', 'node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d', 'node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46']
# 2023-11-30 17:51:12,034 fedbiomed WARNING - Encryption factors are provided while secagg random is None. Please make sure secure aggregation steps are applied correctly.
# 2023-11-30 17:51:12,035 fedbiomed INFO - Aggregating encrypted parameters. This process may take some time depending on model size.
# 2023-11-30 17:51:12,563 fedbiomed INFO - Aggregating parameters from 3 nodes.
# 2023-11-30 17:51:22,277 fedbiomed DEBUG - Aggregation is completed in 10.17 seconds.
# 2023-11-30 17:51:22,448 fedbiomed INFO - Saved aggregated params for round 3 in /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/aggregated_params_0204d284-f220-4b8d-adc2-6f6d63f3137a.mpk
# 2023-11-30 17:51:27,806 fedbiomed INFO - breakpoint for round 3 saved at /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/breakpoint_0003
# 2023-11-30 17:51:27,824 fedbiomed INFO - Sampled nodes in round 4 ['node_a3caf782-3838-4b43-a629-0b004bd18194', 'node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d', 'node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46']
# 2023-11-30 17:51:27,853 fedbiomed INFO - Sending request
# 					 To: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:51:27,853 fedbiomed INFO - Sending request
# 					 To: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:51:27,854 fedbiomed INFO - Sending request
# 					 To: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Request: : TRAIN
#  -----------------------------------------------------------------
# 2023-11-30 17:51:27,904 fedbiomed DEBUG - Node: node_a3caf782-3838-4b43-a629-0b004bd18194 polling for the tasks
# 2023-11-30 17:51:27,919 fedbiomed DEBUG - Node: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d polling for the tasks
# 2023-11-30 17:51:27,922 fedbiomed DEBUG - Node: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46 polling for the tasks
# 2023-11-30 17:51:28,070 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.079211
# 					 ---------
# 2023-11-30 17:51:28,886 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.201223
# 					 ---------
# 2023-11-30 17:51:29,149 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 1/100 (1%) | Samples: 48/4800
#  					 Loss: 0.114215
# 					 ---------
# 2023-11-30 17:51:33,014 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.140247
# 					 ---------
# 2023-11-30 17:51:33,339 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.119441
# 					 ---------
# 2023-11-30 17:51:33,921 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 10/100 (10%) | Samples: 480/4800
#  					 Loss: 0.324525
# 					 ---------
# 2023-11-30 17:51:36,829 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.033626
# 					 ---------
# 2023-11-30 17:51:37,921 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.027157
# 					 ---------
# 2023-11-30 17:51:39,100 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 20/100 (20%) | Samples: 960/4800
#  					 Loss: 0.051741
# 					 ---------
# 2023-11-30 17:51:42,711 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.094855
# 					 ---------
# 2023-11-30 17:51:42,884 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.144056
# 					 ---------
# 2023-11-30 17:51:44,465 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.248785
# 					 ---------
# 2023-11-30 17:51:45,091 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 30/100 (30%) | Samples: 1440/4800
#  					 Loss: 0.082548
# 					 ---------
# 2023-11-30 17:51:45,667 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.242029
# 					 ---------
# 2023-11-30 17:51:46,864 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.256376
# 					 ---------
# 2023-11-30 17:51:48,117 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 40/100 (40%) | Samples: 1920/4800
#  					 Loss: 0.053222
# 					 ---------
# 2023-11-30 17:51:48,825 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.228808
# 					 ---------
# 2023-11-30 17:51:49,812 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.076193
# 					 ---------
# 2023-11-30 17:51:51,301 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 50/100 (50%) | Samples: 2400/4800
#  					 Loss: 0.095415
# 					 ---------
# 2023-11-30 17:51:52,020 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.037004
# 					 ---------
# 2023-11-30 17:51:53,187 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.387605
# 					 ---------
# 2023-11-30 17:51:54,940 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.012042
# 					 ---------
# 2023-11-30 17:51:56,143 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.127465
# 					 ---------
# 2023-11-30 17:51:56,475 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.017447
# 					 ---------
# 2023-11-30 17:51:57,555 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 60/100 (60%) | Samples: 2880/4800
#  					 Loss: 0.096112
# 					 ---------
# 2023-11-30 17:51:58,554 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.042559
# 					 ---------
# 2023-11-30 17:52:01,569 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.169232
# 					 ---------
# 2023-11-30 17:52:01,828 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 Round 5 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.237642
# 					 ---------
# 2023-11-30 17:52:01,956 fedbiomed INFO - INFO
# 					 NODE node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:52:02,417 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 Round 5 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.254977
# 					 ---------
# 2023-11-30 17:52:02,449 fedbiomed INFO - INFO
# 					 NODE node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:52:02,483 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 70/100 (70%) | Samples: 3360/4800
#  					 Loss: 0.094775
# 					 ---------
# 2023-11-30 17:52:03,288 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 80/100 (80%) | Samples: 3840/4800
#  					 Loss: 0.115156
# 					 ---------
# 2023-11-30 17:52:04,096 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 90/100 (90%) | Samples: 4320/4800
#  					 Loss: 0.283713
# 					 ---------
# 2023-11-30 17:52:04,335 fedbiomed INFO - INFO
# 					 NODE node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:52:04,865 fedbiomed INFO - TRAINING
# 					 NODE_ID: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 Round 5 Epoch: 1 | Iteration: 100/100 (100%) | Samples: 4800/4800
#  					 Loss: 0.056430
# 					 ---------
# 2023-11-30 17:52:04,899 fedbiomed INFO - INFO
# 					 NODE node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 MESSAGE: Encrypting model parameters. This process can take some time depending on model size.
# -----------------------------------------------------------------
# 2023-11-30 17:52:05,023 fedbiomed INFO - INFO
# 					 NODE node_a3caf782-3838-4b43-a629-0b004bd18194
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:52:06,497 fedbiomed INFO - INFO
# 					 NODE node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d
# 					 MESSAGE: Encryption is completed!
# -----------------------------------------------------------------
# 2023-11-30 17:52:06,836 fedbiomed INFO - Nodes that successfully reply in round 4 ['node_a3caf782-3838-4b43-a629-0b004bd18194', 'node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d', 'node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46']
# 2023-11-30 17:52:06,837 fedbiomed WARNING - Encryption factors are provided while secagg random is None. Please make sure secure aggregation steps are applied correctly.
# 2023-11-30 17:52:06,838 fedbiomed INFO - Aggregating encrypted parameters. This process may take some time depending on model size.
# 2023-11-30 17:52:07,368 fedbiomed INFO - Aggregating parameters from 3 nodes.
# 2023-11-30 17:52:17,681 fedbiomed DEBUG - Aggregation is completed in 10.76 seconds.
# 2023-11-30 17:52:17,865 fedbiomed INFO - Saved aggregated params for round 4 in /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/aggregated_params_dabdaf82-f030-4c3d-bf77-f3563b94641a.mpk
# 2023-11-30 17:52:25,796 fedbiomed INFO - breakpoint for round 4 saved at /workspaces/Projects/fedbiomed/var/experiments/Experiment_0042/breakpoint_0004
# 5
# 2023-11-30 17:52:27,897 fedbiomed DEBUG - Node: node_a3caf782-3838-4b43-a629-0b004bd18194 polling for the tasks
# 2023-11-30 17:52:27,921 fedbiomed DEBUG - Node: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d polling for the tasks
# 2023-11-30 17:52:27,924 fedbiomed DEBUG - Node: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46 polling for the tasks
# 2023-11-30 17:53:27,899 fedbiomed DEBUG - Node: node_a3caf782-3838-4b43-a629-0b004bd18194 polling for the tasks
# 2023-11-30 17:53:27,923 fedbiomed DEBUG - Node: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d polling for the tasks
# 2023-11-30 17:53:27,926 fedbiomed DEBUG - Node: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46 polling for the tasks
# 2023-11-30 17:54:27,902 fedbiomed DEBUG - Node: node_a3caf782-3838-4b43-a629-0b004bd18194 polling for the tasks
# 2023-11-30 17:54:27,928 fedbiomed DEBUG - Node: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d polling for the tasks
# 2023-11-30 17:54:27,931 fedbiomed DEBUG - Node: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46 polling for the tasks
# 2023-11-30 17:55:27,905 fedbiomed DEBUG - Node: node_a3caf782-3838-4b43-a629-0b004bd18194 polling for the tasks
# 2023-11-30 17:55:27,931 fedbiomed DEBUG - Node: node_4f771acc-bf3c-4d7c-84fc-75c941b1c26d polling for the tasks
# 2023-11-30 17:55:27,935 fedbiomed DEBUG - Node: node_976f4d3a-6c68-47e5-9db2-b4493bcf5e46 polling for the tasks

# %% [markdown]
# Display context after running one round of training.

# %%
print("Secagg Biprime context: ", exp.secagg.biprime.context)
print("Secagg Servkey context: ", exp.secagg.servkey.context)

# %% [markdown]
# #### Changes in experiment triggers re-creation of secure aggregation context
#
# The changes that re-create jobs like adding new node to the experiment will trigger automatic secure aggregation re-setup for the next round.

# %%
# sends new dataset search request
from fedbiomed.researcher.strategies import DefaultStrategy
from fedbiomed.researcher.aggregators.fedavg import FedAverage
exp.set_training_data(None, True)
exp.set_strategy(DefaultStrategy)
exp.set_aggregator(FedAverage)
exp.set_job()

# %%
exp.run_once(increase=True)

# %% [markdown]
# ### Changing arguments of secure aggregation

# %% [markdown]
# Setting `secagg` argument `True` in `Experiment` creates a default `SecureAggregation` instance. Additionally, It is also possible to create `SecureAggregation` instance and pass it as an argument. Here are the arguments that can be set for the `SecureAggregation`
#
# - `active`: `True` if the round will use secure aggregation. Default is `True`
# - `clipping_range`: Clipping range that is going be use for quantization of model parameters. Default clipping range is `3`. However, some models can have model weigths greater than `3`. If clipping range is exceeded during the encryption on the nodes, `Experiment` will log a warning message. In such cases, you can provide a higher clipping range through the argument `clipping_range`.

# %%
from fedbiomed.researcher.secagg import SecureAggregation
secagg = SecureAggregation(
    active=True, 
    clipping_range=100,
    
)
exp.set_secagg(secagg=secagg)

# %%
exp.run_once(increase=True)

# %% [markdown]
# ### Load experiment from a breakpoint
#
# Once a breakpoint is loadded if the context is already exsiting there won't be context setup.

# %%
loaded_exp = Experiment.load_breakpoint()
loaded_exp.info()

# %%
loaded_exp.run_once(increase=True)
